# %% [markdown]
# <a href="https://colab.research.google.com/github/Sai9025/machine-learning/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
Df = pd.read_csv("cars.csv")

# %%
Df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
Df.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
Df['Airbags'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        12
# 1         8
# 2         2
# 3         0
# 4         4
#          ..
# 19232     5
# 19233     8
# 19234     4
# 19235     4
# 19236    12
# Name: Airbags, Length: 19237, dtype: int64>

# %%
import matplotlib.pyplot as plt
y=Df['Airbags']
plt.boxplot(y)
plt.show()

# %%
Df.groupby(['Model','Price']).mean()
# Out:
#                       ID  Prod. year  Cylinders  Airbags
# Model  Price
# 09-Mar 6000   45791286.0      2008.0        6.0      6.0
#        7840   45807151.0      2003.0        4.0      0.0
# 100    549    45808578.0      2014.0        6.0     12.0
#        25089  45806616.0      2016.0        6.0     12.0
# 100 NX 5331   45808410.0      2015.0        4.0     12.0
# ...                  ...         ...        ...      ...
# tC     21950  45441243.0      2014.0        4.0      6.0
#        24775  45806664.0      2014.0        4.0     12.0
# xD     14113  45172859.0      2010.0        4.0      8.0
#        14583  45320577.0      2009.0        4.0      8.0
#        14897  45757908.0      2014.0        4.0     12.0
#
# [10644 rows x 4 columns]

# %%
Df.groupby(['Model','Price']).median()
# Out:
#                       ID  Prod. year  Cylinders  Airbags
# Model  Price
# 09-Mar 6000   45791286.0      2008.0        6.0      6.0
#        7840   45807151.0      2003.0        4.0      0.0
# 100    549    45808578.0      2014.0        6.0     12.0
#        25089  45806616.0      2016.0        6.0     12.0
# 100 NX 5331   45808410.0      2015.0        4.0     12.0
# ...                  ...         ...        ...      ...
# tC     21950  45441243.0      2014.0        4.0      6.0
#        24775  45806664.0      2014.0        4.0     12.0
# xD     14113  45172859.0      2010.0        4.0      8.0
#        14583  45320577.0      2009.0        4.0      8.0
#        14897  45757908.0      2014.0        4.0     12.0
#
# [10644 rows x 4 columns]

# %%
Df.groupby(['Model','Price']).std()
# Out:
#               ID  Prod. year  Cylinders  Airbags
# Model  Price
# 09-Mar 6000  NaN         NaN        NaN      NaN
#        7840  NaN         NaN        NaN      NaN
# 100    549   NaN         NaN        NaN      NaN
#        25089 NaN         NaN        NaN      NaN
# 100 NX 5331  NaN         NaN        NaN      NaN
# ...           ..         ...        ...      ...
# tC     21950 NaN         NaN        NaN      NaN
#        24775 NaN         NaN        NaN      NaN
# xD     14113 NaN         NaN        NaN      NaN
#        14583 NaN         NaN        NaN      NaN
#        14897 NaN         NaN        NaN      NaN
#
# [10644 rows x 4 columns]

# %%
Df.groupby(['Model','Price']).sum()
# Out:
#                     ID  Prod. year  Cylinders  Airbags
# Model  Price
# 09-Mar 6000   45791286        2008        6.0        6
#        7840   45807151        2003        4.0        0
# 100    549    45808578        2014        6.0       12
#        25089  45806616        2016        6.0       12
# 100 NX 5331   45808410        2015        4.0       12
# ...                ...         ...        ...      ...
# tC     21950  45441243        2014        4.0        6
#        24775  45806664        2014        4.0       12
# xD     14113  45172859        2010        4.0        8
#        14583  45320577        2009        4.0        8
#        14897  45757908        2014        4.0       12
#
# [10644 rows x 4 columns]

# %%
missing_values_count = Df.isnull().sum()

# %%
missing_values_count
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
Df.dropna()
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
Df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
Df.tail()
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year Category  \
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999    Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011    Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010     Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007     Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012    Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 19232              Yes       CNG     2.0 Turbo  300000 km        4.0
# 19233              Yes    Petrol           2.4  161600 km        4.0
# 19234              Yes    Diesel             2  116365 km        4.0
# 19235              Yes    Diesel             2   51258 km        4.0
# 19236              Yes    Hybrid           2.4  186923 km        4.0
#
#       Gear box type Drive wheels   Doors       Wheel   Color  Airbags
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
Df.nunique()
# Out:
# ID                  18924
# Price                2315
# Levy                  559
# Manufacturer           65
# Model                1590
# Prod. year             54
# Category               11
# Leather interior        2
# Fuel type               7
# Engine volume         107
# Mileage              7687
# Cylinders              13
# Gear box type           4
# Drive wheels            3
# Doors                   3
# Wheel                   2
# Color                  16
# Airbags                17
# dtype: int64

# %%
Df.Model.loc[:].unique()
# Out:
# array(['RX 450', 'Equinox', 'FIT', ..., 'E 230 124', 'RX 450 F SPORT',
#        'Prius C aqua'], dtype=object)

# %%
Df['Model'].loc[:].unique()
# Out:
# array(['RX 450', 'Equinox', 'FIT', ..., 'E 230 124', 'RX 450 F SPORT',
#        'Prius C aqua'], dtype=object)

# %%
Df['Model'].loc[:50].unique()  #unique() method represents the return of unique value.
# Out:
# array(['RX 450', 'Equinox', 'FIT', 'Escape', 'Santa FE', 'Prius',
#        'Sonata', 'Camry', 'RX 350', 'E 350', 'Transit', 'Vectra', 'CHR',
#        'Elantra', 'RX 400', 'E 220', 'GX 470', 'Highlander', 'Vito',
#        'Cayenne', 'X5', 'Grand Cherokee', 'CHR Limited', 'H1', 'Jetta',
#        'Tacoma', 'Prius C', 'Aqua', 'Escape Hybrid', 'Civic'],
#       dtype=object)

# %%
Df.Model.loc[:50].nunique()  #nunique() method represent the return by its number of unique values.
# Out:
# 30

# %%
Df['Model'].nunique()
# Out:
# 1590

# %%
Df['Price'].describe()
# Out:
# count    1.923700e+04
# mean     1.855593e+04
# std      1.905813e+05
# min      1.000000e+00
# 25%      5.331000e+03
# 50%      1.317200e+04
# 75%      2.207500e+04
# max      2.630750e+07
# Name: Price, dtype: float64

# %%
x=list(Df['Model'])
y=list(Df['Price'])
plt.hist(y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(12, 7))
sns.heatmap(Df.drop(['Model','Price'],axis=1).corr())
plt.show()

# %%
plt.figure(figsize=(12, 7))
sns.pairplot(Df.drop(['Model','Price'],axis=1).corr())
plt.show()

# %%
Df.dtypes
# Out:
# ID                    int64
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %%
Df.dropna(subset=['ID'])
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df=Df.replace(1399,"nan")
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...
